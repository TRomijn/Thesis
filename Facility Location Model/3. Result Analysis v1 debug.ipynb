# %%
import pickle

# %%
import pandas as pd

# %%
case = "Nepal"
output_folder = "Output_testing3"

rob_oois = [
    'total_costs_regret', 'nr_uncovered_DPs_regret',
    'total_uncovered_demand_regret', 'max_distr_time_regret',
    'max_distr_time_sigN', 'nr_uncovered_DPs_sigN', 'total_costs_sigN',
    'total_uncovered_demand_sigN'
]

# %%
# Load data (deserialize)
with open('{}/{}/python_objects.pickle'.format(case, output_folder),
          'rb') as handle:
    global_label_tree, EMA_model_dict, global_dfs_var_unc_data, global_fixed_unc, global_policy_tree = pickle.load(
        handle)

# %%
# global_label_tree
# EMA_model_dict
# global_dfs_var_unc_data
# global_fixed_unc
# global_policy_tree

# %% [markdown]
# ### All EMA models

# %%
EMA_model_dict['p0n0p1n1']

# %% [markdown]
# ### Implemented FLS

# %% [markdown]
# ### Check Decisions in tree and in tables
#     TODO:
#         Problem is:
#             discrepency between csvs and global policy tree

# %%
global_policy_tree.keys()
# Out:
# dict_keys(['p0n0', 'p0n0p1n1', 'p0n0p1n2', 'p0n0p1n3', 'p0n0p1n4', 'p0n0p1n5', 'p0n0p1n1p2n6', 'p0n0p1n1p2n7', 'p0n0p1n1p2n8', 'p0n0p1n1p2n9', 'p0n0p1n2p2n10', 'p0n0p1n2p2n11', 'p0n0p1n2p2n12', 'p0n0p1n2p2n13', 'p0n0p1n2p2n14', 'p0n0p1n2p2n15', 'p0n0p1n3p2n16', 'p0n0p1n3p2n17', 'p0n0p1n3p2n18', 'p0n0p1n3p2n19', 'p0n0p1n4p2n20', 'p0n0p1n4p2n21', 'p0n0p1n4p2n22', 'p0n0p1n4p2n23', 'p0n0p1n5p2n24', 'p0n0p1n5p2n25', 'p0n0p1n5p2n26', 'p0n0p1n5p2n27', 'p0n0p1n5p2n28', 'p0n0p1n5p2n29'])

# %%
for key in global_policy_tree.keys():
    poldict = global_policy_tree[key]
    print(key,[key2 for key2 in poldict if poldict[key2]==1])
# Out:
# p0n0 []
# p0n0p1n1 ['FLO2']
# p0n0p1n2 ['FLO3']
# p0n0p1n3 ['FLO11']
# p0n0p1n4 ['FLO13']
# p0n0p1n5 ['FLO14']
# p0n0p1n1p2n6 ['FLO2', 'FLO3']
# p0n0p1n1p2n7 ['FLO2', 'FLO4']
# p0n0p1n1p2n8 ['FLO2', 'FLO11']
# p0n0p1n1p2n9 ['FLO2', 'FLO13']
# p0n0p1n2p2n10 ['FLO2', 'FLO3']
# p0n0p1n2p2n11 ['FLO3', 'FLO11']
# p0n0p1n2p2n12 ['FLO3', 'FLO12']
# p0n0p1n2p2n13 ['FLO3', 'FLO13']
# p0n0p1n2p2n14 ['FLO3', 'FLO14']
# p0n0p1n2p2n15 ['FLO3', 'FLO15']
# p0n0p1n3p2n16 ['FLO0', 'FLO11']
# p0n0p1n3p2n17 ['FLO3', 'FLO11']
# p0n0p1n3p2n18 ['FLO11', 'FLO12']
# p0n0p1n3p2n19 ['FLO11', 'FLO13']
# p0n0p1n4p2n20 ['FLO3', 'FLO13']
# p0n0p1n4p2n21 ['FLO11', 'FLO13']
# p0n0p1n4p2n22 ['FLO12', 'FLO13']
# p0n0p1n4p2n23 ['FLO13', 'FLO15']
# p0n0p1n5p2n24 ['FLO2', 'FLO14']
# p0n0p1n5p2n25 ['FLO3', 'FLO14']
# p0n0p1n5p2n26 ['FLO11', 'FLO14']
# p0n0p1n5p2n27 ['FLO12', 'FLO14']
# p0n0p1n5p2n28 ['FLO13', 'FLO14']
# p0n0p1n5p2n29 ['FLO14', 'FLO15']

# %%
def print_originating_from(global_policy_tree, node):
    for key in global_policy_tree.keys():
        if node in key:
            poldict = global_policy_tree[key]
            print(key,[key2 for key2 in poldict if poldict[key2]==1])
            
print_originating_from(global_policy_tree,"n2")
# Out:
# p0n0p1n2 ['FLO3']
# p0n0p1n2p2n10 ['FLO2', 'FLO3']
# p0n0p1n2p2n11 ['FLO3', 'FLO11']
# p0n0p1n2p2n12 ['FLO3', 'FLO12']
# p0n0p1n2p2n13 ['FLO3', 'FLO13']
# p0n0p1n2p2n14 ['FLO3', 'FLO14']
# p0n0p1n2p2n15 ['FLO3', 'FLO15']
# p0n0p1n4p2n20 ['FLO3', 'FLO13']
# p0n0p1n4p2n21 ['FLO11', 'FLO13']
# p0n0p1n4p2n22 ['FLO12', 'FLO13']
# p0n0p1n4p2n23 ['FLO13', 'FLO15']
# p0n0p1n5p2n24 ['FLO2', 'FLO14']
# p0n0p1n5p2n25 ['FLO3', 'FLO14']
# p0n0p1n5p2n26 ['FLO11', 'FLO14']
# p0n0p1n5p2n27 ['FLO12', 'FLO14']
# p0n0p1n5p2n28 ['FLO13', 'FLO14']
# p0n0p1n5p2n29 ['FLO14', 'FLO15']

# %%
set_fls = set()
for key in global_policy_tree.keys():
    poldict = global_policy_tree[key]
    for fl in ([key2 for key2 in poldict if poldict[key2]==1]):
        set_fls.add(fl)
set_fls
# Out:
# {'FLO0', 'FLO11', 'FLO12', 'FLO13', 'FLO14', 'FLO15', 'FLO2', 'FLO3', 'FLO4'}

# %% [markdown]
# ### Plot changes uncertainty ranges

# %%
# global_label_tree

# %%
def shorten_labels(label,lab_list = []):
    if "p" in label:
        for i in range(len(label)):
            if label[-i-1] == "p":
                flag = i
                break
        new_label = label[:-i-1]
        lab_list.append(label)
        return shorten_labels(new_label,lab_list), lab_list


def find_full_trace(label):
    b=[]
    a,b = shorten_labels(label,b)
    return list(reversed(b))

# %%
#neem de eerste uit de laatste periode
label= global_label_tree[sorted(global_label_tree.keys())[-1]][0]
# # for i in global_label_tree.values():
# #     pass

testlabels = list((find_full_trace(label)))

# %%
testlabels
# Out:
# ['p0n0', 'p0n0p1n1', 'p0n0p1n1p2n6']

# %% [markdown]
# Check Progress in MPMORDM v8 file. Not super Interesting

# %% [markdown]
# ### Calculate final performance of all leaves (multi period robust performance)

# %% [markdown]
#     create trace of labels
#     create order of implemented FLs
#     Find robustness performance for each last decision
#     Add performances

# %%
# get labels for last period leaves
last_p = sorted([int(l[1:]) for l in global_label_tree.keys()])[-1]
last_p_labels = global_label_tree["p{}".format(last_p)]

# %%
def find_decision(global_policy_tree,trace):
    """
    for a trace, find all decisions made, in the right sequence
    """
    all_decisions = []
    for key in (trace):
        pol = global_policy_tree[key]
        for key in pol:
            if pol[key] == 1:
                if key not in all_decisions:
                    # print(key)
                    all_decisions.append(key)
    return all_decisions

# %%
performance_dict = {}
#for all leaves
for label in last_p_labels:
    trace = find_full_trace(label)
    # find all decisions made for each leave
    decisions = find_decision(global_policy_tree,trace)
    
    # create dataframe with performance of a leave for each period
    temp_df = pd.DataFrame()
    for i in range(len(trace)-1):
#         print(i)
        testdf = pd.read_csv("{}/{}/nondom_rob_pols{}.csv".format(case,output_folder,trace[i]), index_col=0)
        temp_df = temp_df.append(testdf[testdf.index == int(decisions[i][3:])])
    # Sum performance values of each period
#     print(temp_df.shape)
    performance_dict[label] = temp_df[rob_oois].sum()

# %%
performance_dict
# Out:
# {'p0n0p1n1p2n6': total_costs_regret               1.037325e+05
#  nr_uncovered_DPs_regret          2.900000e+01
#  total_uncovered_demand_regret    9.144408e+04
#  max_distr_time_regret            1.101672e+05
#  max_distr_time_sigN              3.966234e+09
#  nr_uncovered_DPs_sigN            1.188546e+02
#  total_costs_sigN                 1.963754e+09
#  total_uncovered_demand_sigN      1.217251e+09
#  dtype: float64, 'p0n0p1n1p2n7': total_costs_regret               9.768344e+04
#  nr_uncovered_DPs_regret          3.500000e+01
#  total_uncovered_demand_regret    1.570052e+05
#  max_distr_time_regret            1.013994e+05
#  max_distr_time_sigN              4.194129e+09
#  nr_uncovered_DPs_sigN            1.371483e+02
#  total_costs_sigN                 2.940011e+09
#  total_uncovered_demand_sigN      2.151851e+09
#  dtype: float64, 'p0n0p1n1p2n8': total_costs_regret               9.912252e+05
#  nr_uncovered_DPs_regret          2.400000e+01
#  total_uncovered_demand_regret    1.301912e+05
#  max_distr_time_regret            1.290212e+05
#  max_distr_time_sigN              3.583412e+09
#  nr_uncovered_DPs_sigN            1.530930e+02
#  total_costs_sigN                 1.010803e+11
#  total_uncovered_demand_sigN      1.483272e+09
#  dtype: float64, 'p0n0p1n1p2n9': total_costs_regret               9.147582e+05
#  nr_uncovered_DPs_regret          2.400000e+01
#  total_uncovered_demand_regret    1.288103e+05
#  max_distr_time_regret            1.276522e+05
#  max_distr_time_sigN              3.629468e+09
#  nr_uncovered_DPs_sigN            1.714987e+02
#  total_costs_sigN                 9.303054e+10
#  total_uncovered_demand_sigN      1.461109e+09
#  dtype: float64, 'p0n0p1n2p2n10': total_costs_regret               2.785762e+05
#  nr_uncovered_DPs_regret          1.800000e+01
#  total_uncovered_demand_regret    2.250378e+04
#  max_distr_time_regret            9.521991e+04
#  max_distr_time_sigN              2.036280e+09
#  nr_uncovered_DPs_sigN            1.476438e+02
#  total_costs_sigN                 5.867380e+09
#  total_uncovered_demand_sigN      2.522381e+08
#  dtype: float64, 'p0n0p1n2p2n11': total_costs_regret               3.894079e+05
#  nr_uncovered_DPs_regret          1.500000e+01
#  total_uncovered_demand_regret    1.885833e+04
#  max_distr_time_regret            4.978079e+04
#  max_distr_time_sigN              4.854470e+08
#  nr_uncovered_DPs_sigN            1.322284e+02
#  total_costs_sigN                 9.623037e+09
#  total_uncovered_demand_sigN      2.167383e+08
#  dtype: float64, 'p0n0p1n2p2n12': total_costs_regret               5.746668e+05
#  nr_uncovered_DPs_regret          9.000000e+00
#  total_uncovered_demand_regret    9.034222e+03
#  max_distr_time_regret            7.529472e+04
#  max_distr_time_sigN              7.251235e+08
#  nr_uncovered_DPs_sigN            1.191265e+02
#  total_costs_sigN                 2.199009e+10
#  total_uncovered_demand_sigN      1.806028e+08
#  dtype: float64, 'p0n0p1n2p2n13': total_costs_regret               4.259446e+05
#  nr_uncovered_DPs_regret          1.600000e+01
#  total_uncovered_demand_regret    1.829651e+04
#  max_distr_time_regret            4.956594e+04
#  max_distr_time_sigN              5.243318e+08
#  nr_uncovered_DPs_sigN            1.628615e+02
#  total_costs_sigN                 1.105725e+10
#  total_uncovered_demand_sigN      2.205811e+08
#  dtype: float64, 'p0n0p1n2p2n14': total_costs_regret               2.875938e+05
#  nr_uncovered_DPs_regret          1.900000e+01
#  total_uncovered_demand_regret    2.259651e+04
#  max_distr_time_regret            3.286978e+04
#  max_distr_time_sigN              3.439677e+08
#  nr_uncovered_DPs_sigN            1.461393e+02
#  total_costs_sigN                 5.740194e+09
#  total_uncovered_demand_sigN      2.505315e+08
#  dtype: float64, 'p0n0p1n2p2n15': total_costs_regret               3.320040e+05
#  nr_uncovered_DPs_regret          1.700000e+01
#  total_uncovered_demand_regret    2.036608e+04
#  max_distr_time_regret            4.328879e+04
#  max_distr_time_sigN              3.825522e+08
#  nr_uncovered_DPs_sigN            1.432527e+02
#  total_costs_sigN                 7.115035e+09
#  total_uncovered_demand_sigN      2.367581e+08
#  dtype: float64, 'p0n0p1n3p2n16': total_costs_regret               2.282648e+06
#  nr_uncovered_DPs_regret          9.000000e+00
#  total_uncovered_demand_regret    7.870652e+04
#  max_distr_time_regret            8.428728e+04
#  max_distr_time_sigN              8.846168e+08
#  nr_uncovered_DPs_sigN            1.986445e+02
#  total_costs_sigN                 2.688594e+11
#  total_uncovered_demand_sigN      4.463480e+08
#  dtype: float64, 'p0n0p1n3p2n17': total_costs_regret               1.254074e+06
#  nr_uncovered_DPs_regret          1.300000e+01
#  total_uncovered_demand_regret    3.745329e+04
#  max_distr_time_regret            4.824696e+04
#  max_distr_time_sigN              6.143662e+08
#  nr_uncovered_DPs_sigN            1.658663e+02
#  total_costs_sigN                 1.256984e+11
#  total_uncovered_demand_sigN      2.588099e+08
#  dtype: float64, 'p0n0p1n3p2n18': total_costs_regret               2.359396e+06
#  nr_uncovered_DPs_regret          4.000000e+00
#  total_uncovered_demand_regret    7.549730e+04
#  max_distr_time_regret            7.080936e+04
#  max_distr_time_sigN              5.215507e+08
#  nr_uncovered_DPs_sigN            1.668036e+02
#  total_costs_sigN                 2.690966e+11
#  total_uncovered_demand_sigN      4.071972e+08
#  dtype: float64, 'p0n0p1n3p2n19': total_costs_regret               1.982314e+06
#  nr_uncovered_DPs_regret          1.300000e+01
#  total_uncovered_demand_regret    7.970543e+04
#  max_distr_time_regret            4.849396e+04
#  max_distr_time_sigN              5.785657e+08
#  nr_uncovered_DPs_sigN            2.130768e+02
#  total_costs_sigN                 2.080625e+11
#  total_uncovered_demand_sigN      5.343079e+08
#  dtype: float64, 'p0n0p1n4p2n20': total_costs_regret               1.152874e+06
#  nr_uncovered_DPs_regret          1.300000e+01
#  total_uncovered_demand_regret    3.441912e+04
#  max_distr_time_regret            4.034601e+04
#  max_distr_time_sigN              6.354942e+08
#  nr_uncovered_DPs_sigN            2.180771e+02
#  total_costs_sigN                 1.038629e+11
#  total_uncovered_demand_sigN      2.559819e+08
#  dtype: float64, 'p0n0p1n4p2n21': total_costs_regret               1.997931e+06
#  nr_uncovered_DPs_regret          1.100000e+01
#  total_uncovered_demand_regret    7.567491e+04
#  max_distr_time_regret            4.764957e+04
#  max_distr_time_sigN              5.823452e+08
#  nr_uncovered_DPs_sigN            2.329533e+02
#  total_costs_sigN                 2.101505e+11
#  total_uncovered_demand_sigN      5.283746e+08
#  dtype: float64, 'p0n0p1n4p2n22': total_costs_regret               2.169483e+06
#  nr_uncovered_DPs_regret          4.000000e+00
#  total_uncovered_demand_regret    6.947864e+04
#  max_distr_time_regret            6.968784e+04
#  max_distr_time_sigN              5.327388e+08
#  nr_uncovered_DPs_sigN            1.921983e+02
#  total_costs_sigN                 2.583185e+11
#  total_uncovered_demand_sigN      4.258310e+08
#  dtype: float64, 'p0n0p1n4p2n23': total_costs_regret               1.960422e+06
#  nr_uncovered_DPs_regret          1.300000e+01
#  total_uncovered_demand_regret    7.586993e+04
#  max_distr_time_regret            4.764957e+04
#  max_distr_time_sigN              5.994315e+08
#  nr_uncovered_DPs_sigN            2.501694e+02
#  total_costs_sigN                 2.079968e+11
#  total_uncovered_demand_sigN      5.438206e+08
#  dtype: float64, 'p0n0p1n5p2n24': total_costs_regret               2.775410e+05
#  nr_uncovered_DPs_regret          1.700000e+01
#  total_uncovered_demand_regret    2.334708e+04
#  max_distr_time_regret            8.935168e+04
#  max_distr_time_sigN              1.995449e+09
#  nr_uncovered_DPs_sigN            1.510994e+02
#  total_costs_sigN                 6.316266e+09
#  total_uncovered_demand_sigN      2.450614e+08
#  dtype: float64, 'p0n0p1n5p2n25': total_costs_regret               2.654024e+05
#  nr_uncovered_DPs_regret          1.800000e+01
#  total_uncovered_demand_regret    2.342502e+04
#  max_distr_time_regret            2.156089e+04
#  max_distr_time_sigN              3.527337e+08
#  nr_uncovered_DPs_sigN            1.473047e+02
#  total_costs_sigN                 6.036708e+09
#  total_uncovered_demand_sigN      2.456453e+08
#  dtype: float64, 'p0n0p1n5p2n26': total_costs_regret               4.115419e+05
#  nr_uncovered_DPs_regret          1.400000e+01
#  total_uncovered_demand_regret    2.047939e+04
#  max_distr_time_regret            4.730361e+04
#  max_distr_time_sigN              4.772524e+08
#  nr_uncovered_DPs_sigN            1.340810e+02
#  total_costs_sigN                 1.031607e+10
#  total_uncovered_demand_sigN      2.070290e+08
#  dtype: float64, 'p0n0p1n5p2n27': total_costs_regret               6.286130e+05
#  nr_uncovered_DPs_regret          8.000000e+00
#  total_uncovered_demand_regret    9.034222e+03
#  max_distr_time_regret            7.132930e+04
#  max_distr_time_sigN              6.450503e+08
#  nr_uncovered_DPs_sigN            1.213519e+02
#  total_costs_sigN                 2.362473e+10
#  total_uncovered_demand_sigN      1.731145e+08
#  dtype: float64, 'p0n0p1n5p2n28': total_costs_regret               4.424956e+05
#  nr_uncovered_DPs_regret          1.600000e+01
#  total_uncovered_demand_regret    1.901979e+04
#  max_distr_time_regret            4.841321e+04
#  max_distr_time_sigN              4.989120e+08
#  nr_uncovered_DPs_sigN            1.642305e+02
#  total_costs_sigN                 1.073302e+10
#  total_uncovered_demand_sigN      2.194942e+08
#  dtype: float64, 'p0n0p1n5p2n29': total_costs_regret               3.468011e+05
#  nr_uncovered_DPs_regret          1.600000e+01
#  total_uncovered_demand_regret    2.177061e+04
#  max_distr_time_regret            4.261488e+04
#  max_distr_time_sigN              3.953997e+08
#  nr_uncovered_DPs_sigN            1.456125e+02
#  total_costs_sigN                 7.797403e+09
#  total_uncovered_demand_sigN      2.244112e+08
#  dtype: float64}

# %%
performance_multi_period_robust = pd.DataFrame.from_dict(performance_dict, orient="index" )

# %%
performance_multi_period_robust
# Out:
#                total_costs_regret  nr_uncovered_DPs_regret  \
# p0n0p1n1p2n6         1.037325e+05                     29.0
# p0n0p1n1p2n7         9.768344e+04                     35.0
# p0n0p1n1p2n8         9.912252e+05                     24.0
# p0n0p1n1p2n9         9.147582e+05                     24.0
# p0n0p1n2p2n10        2.785762e+05                     18.0
# p0n0p1n2p2n11        3.894079e+05                     15.0
# p0n0p1n2p2n12        5.746668e+05                      9.0
# p0n0p1n2p2n13        4.259446e+05                     16.0
# p0n0p1n2p2n14        2.875938e+05                     19.0
# p0n0p1n2p2n15        3.320040e+05                     17.0
# p0n0p1n3p2n16        2.282648e+06                      9.0
# p0n0p1n3p2n17        1.254074e+06                     13.0
# p0n0p1n3p2n18        2.359396e+06                      4.0
# p0n0p1n3p2n19        1.982314e+06                     13.0
# p0n0p1n4p2n20        1.152874e+06                     13.0
# p0n0p1n4p2n21        1.997931e+06                     11.0
# p0n0p1n4p2n22        2.169483e+06                      4.0
# p0n0p1n5p2n25         3.527337e+08             147.304671      6.036708e+09
# p0n0p1n5p2n26         4.772524e+08             134.080972      1.031607e+10
# p0n0p1n5p2n27         6.450503e+08             121.351853      2.362473e+10
# p0n0p1n5p2n28         4.989120e+08             164.230508      1.073302e+10
# p0n0p1n5p2n29         3.953997e+08             145.612539      7.797403e+09
#
#                total_uncovered_demand_sigN
# p0n0p1n1p2n6                  1.217251e+09
# p0n0p1n1p2n7                  2.151851e+09
# p0n0p1n1p2n8                  1.483272e+09
# p0n0p1n1p2n9                  1.461109e+09
# p0n0p1n2p2n10                 2.522381e+08
# p0n0p1n2p2n11                 2.167383e+08
# p0n0p1n2p2n12                 1.806028e+08
# p0n0p1n2p2n13                 2.205811e+08
# p0n0p1n2p2n14                 2.505315e+08
# p0n0p1n2p2n15                 2.367581e+08
# p0n0p1n3p2n16                 4.463480e+08
# p0n0p1n3p2n17                 2.588099e+08
# p0n0p1n3p2n18                 4.071972e+08
# p0n0p1n3p2n19                 5.343079e+08
# p0n0p1n4p2n20                 2.559819e+08
# p0n0p1n4p2n21                 5.283746e+08
# p0n0p1n4p2n22                 4.258310e+08
# p0n0p1n4p2n23                 5.438206e+08
# p0n0p1n5p2n24                 2.450614e+08
# p0n0p1n5p2n25                 2.456453e+08
# p0n0p1n5p2n26                 2.070290e+08
# p0n0p1n5p2n27                 1.731145e+08
# p0n0p1n5p2n28                 2.194942e+08
# p0n0p1n5p2n29                 2.244112e+08

# %%
plot_optimal(performance_multi_period_robust, rob_oois, "test")

# %% [markdown]
# ### Calculate performance over time

# %%
last_p = max([int(key[1:]) for key in global_label_tree.keys()])
last_p_labels = global_label_tree["p{}".format(last_p)]

# %%
performance_dict = {}
#for all leaves
for label in last_p_labels:
    print(label)
    trace = find_full_trace(label)
    print(trace)
    # find all decisions made for each leave
    decisions = find_decision(global_policy_tree,trace)
    print(decisions)
    
    # create dataframe with performance of a leave for each period
    temp_list = list()
    for i in range(len(trace)-1):
        print(i)
        testdf = pd.read_csv("{}/{}/nondom_rob_pols{}.csv".format(case,output_folder,trace[i]), index_col=0)
        test_array = testdf[testdf.index == int(decisions[i][3:])]
        temp_list.append(float(test_array['total_costs_regret']))
        
#         break
    performance_dict[label] = (temp_list)
#     break
    
    
#     temp_df = temp_df.append(testdf[testdf.pol_i == int(decisions[i][3:])])
#     # Sum performance values of each period
#     performance_dict[label] = temp_df[rob_oois].sum()
# Out:
# p0n0p1n1p2n6
# ['p0n0', 'p0n0p1n1', 'p0n0p1n1p2n6']
# ['FLO2', 'FLO3']
# 0
# 1
# p0n0p1n1p2n7
# ['p0n0', 'p0n0p1n1', 'p0n0p1n1p2n7']
# ['FLO2', 'FLO4']
# 0
# 1
# p0n0p1n1p2n8
# ['p0n0', 'p0n0p1n1', 'p0n0p1n1p2n8']
# ['FLO2', 'FLO11']
# 0
# 1
# p0n0p1n1p2n9
# ['p0n0', 'p0n0p1n1', 'p0n0p1n1p2n9']
# ['FLO2', 'FLO13']
# 0
# 1
# p0n0p1n2p2n10
# ['p0n0', 'p0n0p1n2', 'p0n0p1n2p2n10']
# ['FLO3', 'FLO2']
# 0
# 1
# p0n0p1n2p2n11
# ['p0n0', 'p0n0p1n2', 'p0n0p1n2p2n11']
# ['FLO3', 'FLO11']
# 0
# 1
# p0n0p1n2p2n12
# ['p0n0', 'p0n0p1n2', 'p0n0p1n2p2n12']
# ['FLO3', 'FLO12']
# 0
# 1
# p0n0p1n2p2n13
# ['p0n0', 'p0n0p1n2', 'p0n0p1n2p2n13']
# ['FLO3', 'FLO13']
# 0
# 1
# p0n0p1n2p2n14
# ['p0n0', 'p0n0p1n2', 'p0n0p1n2p2n14']
# ['FLO3', 'FLO14']
# 0
# 1
# p0n0p1n2p2n15
# ['p0n0', 'p0n0p1n2', 'p0n0p1n2p2n15']
# ['FLO3', 'FLO15']
# 0
# 1
# p0n0p1n3p2n16
# ['p0n0', 'p0n0p1n3', 'p0n0p1n3p2n16']
# ['FLO11', 'FLO0']
# 0
# 1
# p0n0p1n3p2n17
# ['p0n0', 'p0n0p1n3', 'p0n0p1n3p2n17']
# ['FLO11', 'FLO3']
# 0
# 1
# p0n0p1n3p2n18
# ['p0n0', 'p0n0p1n3', 'p0n0p1n3p2n18']
# ['FLO11', 'FLO12']
# 0
# 1
# p0n0p1n3p2n19
# ['p0n0', 'p0n0p1n3', 'p0n0p1n3p2n19']
# ['FLO11', 'FLO13']
# 0
# 1
# p0n0p1n4p2n20
# ['p0n0', 'p0n0p1n4', 'p0n0p1n4p2n20']
# ['FLO13', 'FLO3']
# 0
# 1
# p0n0p1n4p2n21
# ['p0n0', 'p0n0p1n4', 'p0n0p1n4p2n21']
# ['FLO13', 'FLO11']
# 0
# 1
# p0n0p1n4p2n22
# ['p0n0', 'p0n0p1n4', 'p0n0p1n4p2n22']
# ['FLO13', 'FLO12']
# 0
# 1
# p0n0p1n4p2n23
# ['p0n0', 'p0n0p1n4', 'p0n0p1n4p2n23']
# ['FLO13', 'FLO15']
# 0
# 1
# p0n0p1n5p2n24
# ['p0n0', 'p0n0p1n5', 'p0n0p1n5p2n24']
# ['FLO14', 'FLO2']
# 0
# 1
# p0n0p1n5p2n25
# ['p0n0', 'p0n0p1n5', 'p0n0p1n5p2n25']
# ['FLO14', 'FLO3']
# 0
# 1
# p0n0p1n5p2n26
# ['p0n0', 'p0n0p1n5', 'p0n0p1n5p2n26']
# ['FLO14', 'FLO11']
# 0
# 1
# p0n0p1n5p2n27
# ['p0n0', 'p0n0p1n5', 'p0n0p1n5p2n27']
# ['FLO14', 'FLO12']
# 0
# 1
# p0n0p1n5p2n28
# ['p0n0', 'p0n0p1n5', 'p0n0p1n5p2n28']
# ['FLO14', 'FLO13']
# 0
# 1
# p0n0p1n5p2n29
# ['p0n0', 'p0n0p1n5', 'p0n0p1n5p2n29']
# ['FLO14', 'FLO15']
# 0
# 1

# %%
test = find_full_trace("p0n0p1n2p2n10")

# %%
test
# Out:
# ['p0n0', 'p0n0p1n2', 'p0n0p1n2p2n10']

# %%
find_decision(global_policy_tree,test)
# Out:
# ['FLO3', 'FLO2']

# %%
global_policy_tree.keys()
# Out:
# dict_keys(['p0n0', 'p0n0p1n1', 'p0n0p1n2', 'p0n0p1n3', 'p0n0p1n4', 'p0n0p1n5', 'p0n0p1n1p2n6', 'p0n0p1n1p2n7', 'p0n0p1n1p2n8', 'p0n0p1n1p2n9', 'p0n0p1n2p2n10', 'p0n0p1n2p2n11', 'p0n0p1n2p2n12', 'p0n0p1n2p2n13', 'p0n0p1n2p2n14', 'p0n0p1n2p2n15', 'p0n0p1n3p2n16', 'p0n0p1n3p2n17', 'p0n0p1n3p2n18', 'p0n0p1n3p2n19', 'p0n0p1n4p2n20', 'p0n0p1n4p2n21', 'p0n0p1n4p2n22', 'p0n0p1n4p2n23', 'p0n0p1n5p2n24', 'p0n0p1n5p2n25', 'p0n0p1n5p2n26', 'p0n0p1n5p2n27', 'p0n0p1n5p2n28', 'p0n0p1n5p2n29'])

# %%
global_policy_tree["p0n0p1n2p2n10"]
# Out:
# {'FLO0': 0.0,
#  'FLO1': 0.0,
#  'FLO2': 1.0,
#  'FLO3': 1.0,
#  'FLO4': 0.0,
#  'FLO5': 0.0,
#  'FLO6': 0.0,
#  'FLO7': 0.0,
#  'FLO8': 0.0,
#  'FLO9': 0.0,
#  'FLO10': 0.0,
#  'FLO11': 0.0,
#  'FLO12': 0.0,
#  'FLO13': 0.0,
#  'FLO14': 0.0,
#  'FLO15': 0.0,
#  'FLO16': 0.0,
#  'FLO17': 0.0,
#  'FLO18': 0.0,
#  'FLO19': 0.0}

# %%
testdf
# Out:
#     total_costs_regret  nr_uncovered_DPs_regret  \
# 2         12352.548038                      9.0
# 3           213.918403                     10.0
# 11       146353.416306                      6.0
# 12       363424.542228                      0.0
# 13       177307.085800                      8.0
# 15        81612.651962                      8.0
#
#     total_uncovered_demand_regret  max_distr_time_regret  max_distr_time_sigN  \
# 2                    14312.855582           67790.785719         1.822322e+09
# 3                    14390.794126               0.000000         1.796061e+08
# 11                   11445.166613           25742.715257         3.041248e+08
# 12                       0.000000           49768.411384         4.719227e+08
# 13                    9985.564763           26852.315544         3.257844e+08
# 15                   12736.385103           21053.986318         2.222721e+08
#
#     nr_uncovered_DPs_sigN  total_costs_sigN  total_uncovered_demand_sigN
# 2               76.767076      2.220184e+09                 1.117051e+08
# 3               72.972350      1.940627e+09                 1.122890e+08
# 11              59.748652      6.219991e+09                 7.367261e+07
# 12              47.019533      1.952865e+10                 3.975812e+07
# 13              89.898188      6.636933e+09                 8.613780e+07
# 15              71.280219      3.701321e+09                 9.105482e+07

# %%
float(test_array['total_costs_regret'])
# Out:
# 330674.139492144

# %%
rob_oois[0]
# Out:
# 'total_costs_regret'
