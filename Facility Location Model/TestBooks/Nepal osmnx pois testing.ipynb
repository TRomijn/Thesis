# %%
import osmnx as ox

# %%
gdf = ox.pois_from_place(place='Uitgeest, Netherlands')

# %%
gdf.plot()

# %%
gdf.amenity.value_counts()
# Out:
# parking             147
# bench                39
# restaurant           23
# school               23
# waste_basket         18
# bicycle_parking      18
# recycling            17
# fast_food            10
# place_of_worship      9
# fuel                  8
# cafe                  5
# doctors               5
# waste_disposal        5
# social_facility       4
# dentist               4
# pub                   4
# fire_station          3
# bank                  3
# pharmacy              3
# atm                   2
# childcare             2
# charging_station      2
# ferry_terminal        2
# drinking_water        1
# townhall              1
# toilets               1
# grave_yard            1
# post_office           1
# community_centre      1
# car_wash              1
# venue                 1
# post_box              1
# library               1
# swimming_pool         1
# veterinary            1
# music_school          1
# canoe_rental          1
# Name: amenity, dtype: int64

# %%
place = "Delft, Netherlands"

# %%
hospitals = ox.pois_from_place(place=place, amenities=['hospital'])

# %%
hospitals.plot()

# %%
place = 'zuid holland, Netherlands'

# %%
hospital_zh = ox.pois_from_place(place=place, amenities=['hospital'])

# %%
hospital_zh.plot()

# %%
place= "delft, zuid holland"

# %%
delft_poly = ox.gdf_from_place(place)

# %%
delft_poly.plot()

# %%
universities = ox.pois_from_polygon(delft_poly.geometry.values[0],amenities=['university'])

# %%
universities.name.unique()
# Out:
# array([nan, 'main entrance', 'employee entrance', 'entrance_1',
#        'entrance_2', 'entrance_3',
#        'Faculty of Industrial Design Engineering', 'F',
#        'IHE Delft Institute for Water Education', 'A', 'C', 'B2', 'C2',
#        'B1', 'P', 'D1', 'D2', 'D3', 'E TNO', 'Faculty of Architecture',
#        'Bouwpub', 'Ketelhuis', 'TU Aula Congrescentrum',
#        'Faculty of Applied Sciences', 'Process & Energy Lab',
#        'Stevin III', 'Faculty of Civil Engineering and Geosciences',
#        'The Fellowship', 'TNO', 'OTB Research Institute',
#        'Aerospace Engineering', 'Vliegtuighal', 'SIMONA',
#        'Faculty of Technology Policy and Management',
#        'Technische Universiteit Delft', 'Gebouw 35', 'Stevin II',
#        'TU Delft - Wiskunde en Informatica', 'Pulse', 'EWI hoogbouw',
#        'EWI laagbouw', 'High Voltage Laboratory', 'Gebouw 64',
#        'Faculty of Mechanical, Maritime and Material Engineering (3mE)'],
#       dtype=object)

# %%
universities.name.value_counts().head()
# Out:
# Faculty of Industrial Design Engineering        2
# Aerospace Engineering                           2
# Faculty of Technology Policy and Management     2
# OTB Research Institute                          2
# Faculty of Civil Engineering and Geosciences    2
# Name: name, dtype: int64

# %%
universities.plot()

# %%
all_pois = ox.pois_from_place("Kathmandu, Nepal")

# %%
len(all_pois)
# Out:
# 8004

# %%
all_pois['Amenity'].unique()
# Out:
# array([nan, 'Link Marg'], dtype=object)

# %%
hospitals = ox.pois_from_place(place="Nepal", amenities=['hospital'])

# %%
hospitals.plot(markersize=1)

# %%
roads = ox.graph_from_place("Den Haag", infrastructure='way["highway"]')

# %%
ox.plot_graph(roads)
# Out:
# (<Figure size 673.312x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2a78c81b208>)

# %%
motorways = ox.graph_from_place("Den Haag", infrastructure='way["highway"~"motorway"]')

# %%
ox.plot_graph(motorways)
# Out:
# (<Figure size 542.906x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2a78c846dd8>)

# %%
motorways = ox.graph_from_place("Nepal", infrastructure='way["highway"~"trunk"]', max_query_area_size=250000000000)

# %%
ox.plot_graph(motorways)
# Out:
# (<Figure size 1345.59x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2a78bccec50>)

# %%
motorways2 = ox.project_graph(motorways)

# %%
ox.plot_graph(motorways2)
# Out:
# (<Figure size 2000.05x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2a78c555da0>)

# %% [markdown]
# ## All pois from Nepal

# %%
Nepal_pois = ox.pois_from_place(place='Nepal')

# %%
POI_count_nepal = Nepal_pois.amenity.value_counts()

# %%
POI_count_nepal.to_csv("NEPAL_POI_Count.csv")

# %%
# Save a dictionary into a pickle file.
import pickle

# favorite_color = { "lion": "yellow", "kitty": "red" }

#

# %%
pickle.dump( Nepal_pois, open( "nepal_pois.p", "wb" ) )

# %%
Nepal_pois2 = pickle.load( open( "nepal_pois.p", "rb" ) )
