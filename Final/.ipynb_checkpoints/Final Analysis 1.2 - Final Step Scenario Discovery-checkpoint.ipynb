# %%
import numpy as np
import pandas as pd
import pickle

# %%
case = 'Nepal'
output_folder = "Simulation-results"

# %%
with open('{}/{}/python_objects.pickle'.format(case, output_folder),
          'rb') as handle:
    global_label_tree, EMA_model_dict, global_dfs_var_unc_data, global_fixed_unc, global_policy_tree = pickle.load(
        handle)

# %%
global_label_tree['p3'][0]
# Out:
# 'p0n0p1n1p2n7p3n45'

# %%
from ema_workbench import load_results
import ema_workbench.analysis.prim as prim

from ema_workbench import ema_logging
# from ema_workbench.em_framework.

ema_logging.log_to_stderr(ema_logging.INFO)

import matplotlib.pyplot as plt
# %matplotlib notebook
# Out:
# C:\Users\timro\Anaconda3\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)

# %%
results = load_results("{}/{}/p0n0p1n1p2n8p3n53.tar.gz".format(case,output_folder))
# Out:
# [MainProcess/INFO] results loaded succesfully from C:\Users\timro\Dropbox\MSc EPA\0 Master Thesis\Python Files\Thesis\Final\Nepal\Simulation-results\p0n0p1n1p2n8p3n53.tar.gz

# %%
results[1].keys()
# Out:
# dict_keys(['total_costs', 'nr_uncovered_DPs', 'total_uncovered_demand', 'max_distr_time'])

# %%
# %matplotlib notebook

# %% [markdown]
# ## Costs

# %%
def classify_totcosts(data):
    #get the output 
    result = data['total_costs']
    #get threshold worst 20%, assuming minimisation
    worst_20 = np.percentile(result, 80)
    
    #make an empty array of length equal to number of cases 
    classes =  np.zeros(result.shape[0])
    
    #if higher than threshold of worst 20%
    classes[result[:] > worst_20] = 1
    
    return classes

# %%
prim_obj = prim.setup_prim(results, classify_totcosts, threshold=0.8)

box1 = prim_obj.find_box()
# Out:
# [MainProcess/INFO] 2000 points remaining, containing 400 cases of interest
# C:\Users\timro\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# [MainProcess/INFO] mean: 1.0, mass: 0.078, coverage: 0.39, density: 1.0 restricted_dimensions: 10

# %%
box1.show_tradeoff()
plt.title("Peeling Trajectory for Total Costs")
# plt.savefig("{}/{}/Analysis/ScenDisc/Peeling_Traj_TTC".format(case,output_folder),dpi=400,bbox_inches='tight')
plt.show()

# %%
box1.inspect(14)
box1.inspect(14, style="graph", )
# box1.inspect(25)
# box1.inspect(25, style="graph", )
plt.title("Box limits Total Transport Costs")
# plt.tight_layout()
# plt.savefig("{}/{}/Analysis/ScenDisc/Box_Lim_TTC".format(case,output_folder),dpi=400,bbox_inches='tight')
plt.show()
# Out:
# coverage        0.97
# density     0.405858
# mass           0.478
# mean        0.405858
# res dim            3
# Name: 14, dtype: object
#
#                         box 14
#                            min        max                 qp values
# unit_transport_cost   0.880027   1.999837   [5.013345602934717e-09]
# demand_per_affected  19.628996  49.931413  [5.7964583228401567e-08]
# FL_range              2.792149   5.999498    [9.08625115097314e-06]

# %%
# test
box1.inspect(46)
box1.inspect(46, style="graph", )
# box1.inspect(25)
# box1.inspect(25, style="graph", )
# plt.title("Box limits Total Transport Costs")
# plt.tight_layout()
# plt.savefig("{}/{}/Analysis/ScenDisc/Box_Lim_TTC".format(case,output_folder),dpi=400,bbox_inches='tight')
plt.show()
# Out:
# coverage     0.39
# density         1
# mass        0.078
# mean            1
# res dim        10
# Name: 46, dtype: object
#
#                         box 46             \
#                            min        max
# FL_range              4.624947   5.999498
# demand_per_affected  26.170500  49.931413
# unit_transport_cost   1.099458   1.999837
# DSRFL14               1.329567   1.585243
# DSRDP15               1.199953   1.290865
# DSRDP29               1.180112   1.451835
# DSRDP3                1.664288   1.929248
# DSRFL1                1.350212   1.644066
# DSRFL10               1.720143   1.873085
# DSRDP32               1.064297   1.565627
#
#
#                                                      qp values
# FL_range                               [8.893151384959388e-44]
# demand_per_affected                    [1.727317657913393e-24]
# unit_transport_cost                   [2.5608985946442736e-17]
# DSRFL14                                 [0.003930284753840204]
# DSRDP15                                   [0.0044674073665431]
# DSRDP29                                  [0.02123620939144855]
# DSRDP3                                    [0.1405362207823536]
# DSRFL1                                    [0.1474694203550035]
# DSRFL10              [0.15438808666286377, 0.1405362207823536]
# DSRDP32                                                  [1.0]

# %%
box1.select(14)
fig = box1.show_pairs_scatter()
# fig.set_size_inches((12,12))
# plt.tight_layout()
plt.show()

# %%
box2 = prim_obj.find_box()
# Out:
# [MainProcess/INFO] 1044 points remaining, containing 12 cases of interest
# C:\Users\timro\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# [MainProcess/INFO] box does not meet threshold criteria, value is 0.11764705882352941, returning dump box

# %%
print (prim_obj.stats_to_dataframe())
print (prim_obj.boxes_to_dataframe())
# Out:
#        coverage   density   mass  res_dim
# box 1      0.97  0.405858  0.478        3
# box 2      0.03  0.011494  0.522        0
#                         box 1              box 2
#                           min      max       min      max
# unit_transport_cost  0.880027  1.99984  0.502216  1.99984
# demand_per_affected    19.629  49.9314   10.0768  49.9314
# FL_range              2.79215   5.9995    2.0042   5.9995

# %% [markdown]
# ## Travel Time

# %%
def classify_max_trav_t(data):
    #get the output 
    result = data['max_distr_time']
    #get threshold worst 20%, assuming minimisation
    worst_20 = np.percentile(result, 80)
    
    #make an empty array of length equal to number of cases 
    classes =  np.zeros(result.shape[0])
    
    #if higher than threshold of worst 20%
    classes[result[:] > worst_20] = 1
    
    return classes

# %%
prim_obj = prim.setup_prim(results, classify_max_trav_t, threshold=0.8)

box1 = prim_obj.find_box()
# Out:
# [MainProcess/INFO] 3000 points remaining, containing 600 cases of interest
# C:\Users\timro\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# [MainProcess/INFO] mean: 1.0, mass: 0.19666666666666666, coverage: 0.9833333333333333, density: 1.0 restricted_dimensions: 2

# %%
# box1.show_ppt()
# plt.show()

box1.show_tradeoff()
plt.title("Peeling Trajectory for Maximum Travel Time")
plt.show()

# %%
box1.inspect(26)
box1.inspect(26, style="graph")
# box1.inspect(39)
# box1.inspect(39, style="graph")
plt.title("Box limits Maximum Travel Time")
plt.savefig("{}/{}/Analysis/ScenDisc/Box_Lim_MTT".format(case,output_folder),dpi=400,bbox_inches='tight')
plt.show()
# Out:
# coverage           1
# density     0.909091
# mass            0.22
# mean        0.909091
# res dim            2
# Name: 26, dtype: object
#
#                      box 26
#                         min                 max                 qp values
# DSRDP34             1.54355              1.6837  [1.097889650222689e-293]
# policy   {6, 9, 10, 11, 12}  {6, 9, 10, 11, 12}   [8.751976393787312e-24]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-e129b4e255bf> in <module>()
#       4 # box1.inspect(39, style="graph")
#       5 plt.title("Box limits Maximum Travel Time")
# ----> 6 plt.savefig("{}/{}/Analysis/ScenDisc/Box_Lim_MTT".format(case,output_folder),dpi=400,bbox_inches='tight')
#       7 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     708 def savefig(*args, **kwargs):
#     709     fig = gcf()
# --> 710     res = fig.savefig(*args, **kwargs)
#     711     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     712     return res
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     524
#     525         try:
# --> 526             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     527                 _png.write_png(renderer._renderer, fh,
#     528                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     622 def open_file_cm(path_or_file, mode="r", encoding=None):
#     623     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 624     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     625     if opened:
#     626         with fh:
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     607             fh = bz2.BZ2File(fname, flag)
#     608         else:
# --> 609             fh = io.open(fname, flag, encoding=encoding)
#     610         opened = True
#     611     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Nepal/Simulation-results/Analysis/ScenDisc/Box_Lim_MTT.png'

# %%
print("doesnt work because the input is a policy set")
box1.select(39)
fig = box1.show_pairs_scatter()
# fig.set_size_inches((12,12))
# plt.tight_layout()
plt.show()
# Out:
# doesnt work because the input is a policy set
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-184e7f48632d> in <module>()
#       1 print("doesnt work because the input is a policy set")
# ----> 2 box1.select(39)
#       3 fig = box1.show_pairs_scatter()
#       4 # fig.set_size_inches((12,12))
#       5 # plt.tight_layout()
#
# ~\Anaconda3\lib\site-packages\ema_workbench\analysis\prim.py in select(self, i)
#     434
#     435         indices = sdutil._in_box(self.prim.x[self.prim.yi_remaining],
# --> 436                                  self.box_lims[i])
#     437         self.yi = self.prim.yi_remaining[indices]
#     438         self._cur_box = i
#
# IndexError: list index out of range

# %%
box2 = prim_obj.find_box()
# Out:
# [MainProcess/INFO] 1604 points remaining, containing 3 cases of interest
# C:\Users\timro\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# [MainProcess/INFO] box does not meet threshold criteria, value is 0.02857142857142857, returning dump box

# %%
# box2.show_tradeoff()
# plt.title("Box2: Peeling Trajectory for Maximum Travel Time")
# plt.show()

# %%
print (prim_obj.stats_to_dataframe())
print (prim_obj.boxes_to_dataframe())
# Out:
#        coverage  density   mass  res_dim
# box 1  0.992481  1.00000  0.198        2
# box 2  0.007519  0.00187  0.802        0
#                box 1                         box 2
#                  min          max              min              max
# DSRDP34      1.54398      1.68305          1.15326          1.68305
# policy   {10, 3, 13}  {10, 3, 13}  {16, 10, 3, 13}  {16, 10, 3, 13}

# %%
# Check with visual if everything is indeed right
global_policy_tree['p0n0p1n1p2n8p3n53']
# Out:
# {'FLO0': 0.0,
#  'FLO1': 0.0,
#  'FLO2': 0.0,
#  'FLO3': 0.0,
#  'FLO4': 1.0,
#  'FLO5': 0.0,
#  'FLO6': 0.0,
#  'FLO7': 1.0,
#  'FLO8': 0.0,
#  'FLO9': 0.0,
#  'FLO10': 0.0,
#  'FLO11': 1.0,
#  'FLO12': 0.0,
#  'FLO13': 0.0,
#  'FLO14': 0.0,
#  'FLO15': 0.0,
#  'FLO16': 0.0,
#  'FLO17': 0.0,
#  'FLO18': 0.0,
#  'FLO19': 0.0}

# %% [markdown]
# ## Total Uncovered Demand

# %%
def classify_tot_uncov_demand(data):
    #get the output 
    result = data['total_uncovered_demand']
    #get threshold worst 20%, assuming minimisation
    worst_20 = np.percentile(result, 80)
    
    #make an empty array of length equal to number of cases 
    classes =  np.zeros(result.shape[0])
    
    #if higher than threshold of worst 20%
    classes[result[:] > worst_20] = 1
    
    return classes

# %%
prim_obj = prim.setup_prim(results, classify_tot_uncov_demand, threshold=0.8)

box1 = prim_obj.find_box()
# Out:
# [MainProcess/INFO] 2000 points remaining, containing 400 cases of interest
# C:\Users\timro\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# [MainProcess/INFO] mean: 1.0, mass: 0.07, coverage: 0.35, density: 1.0 restricted_dimensions: 20

# %%
# box1.show_ppt()
# plt.show()

box1.show_tradeoff()
plt.title("Peeling Trajectory for Total Uncovered Demand")
# plt.savefig("{}/{}/Analysis/ScenDisc/Peeling_Traj_TUD".format(case,output_folder),dpi=400,bbox_inches='tight')
plt.show()

# %%
box1.inspect(17)
box1.inspect(17, style="graph")
# box1.inspect(20)
# box1.inspect(20, style="graph")
plt.title("Box limits Total Uncovered Demand")
plt.savefig("{}/{}/Analysis/ScenDisc/Box_Lim_TUD".format(case,output_folder),dpi=400,bbox_inches='tight')
plt.show()
# box1.inspect(48)
# Out:
# coverage      0.9325
# density     0.457108
# mass           0.408
# mean        0.457108
# res dim            2
# Name: 17, dtype: object
#
#                         box 17
#                            min        max                 qp values
# FL_range              2.004204   3.815895  [3.2162831132379245e-50]
# demand_per_affected  14.525948  49.931413    [0.014134368637062932]

# %%
# print("doesnt work because the input is a policy set")
box1.select(17)
fig = box1.show_pairs_scatter()
# fig.set_size_inches((12,12))
# plt.tight_layout()
plt.show()

# %%
box2 = prim_obj.find_box()
# Out:
# [MainProcess/INFO] 1184 points remaining, containing 27 cases of interest
# C:\Users\timro\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# [MainProcess/INFO] box does not meet threshold criteria, value is 0.27, returning dump box

# %%
print (prim_obj.stats_to_dataframe())
print (prim_obj.boxes_to_dataframe())
# Out:
#        coverage   density   mass  res_dim
# box 1    0.9325  0.457108  0.408        2
# box 2    0.0675  0.022804  0.592        0
#                        box 1             box 2
#                          min      max      min      max
# FL_range              2.0042  3.81589   2.0042   5.9995
# demand_per_affected  14.5259  49.9314  10.0768  49.9314

# %% [markdown]
# ## # Uncovered Demand Points

# %%
def classify_nr_uncov_DPs(data):
    #get the output 
    result = data['nr_uncovered_DPs']
    #get threshold worst 20%, assuming minimisation
    worst_20 = np.percentile(result, 80)
    
    #make an empty array of length equal to number of cases 
    classes =  np.zeros(result.shape[0])
    
    #if higher than threshold of worst 20%
    classes[result[:] > worst_20] = 1
    
    return classes

# %%
prim_obj = prim.setup_prim(results, classify_nr_uncov_DPs, threshold=0.8)

box1 = prim_obj.find_box()
# Out:
# [MainProcess/INFO] 2000 points remaining, containing 388 cases of interest
# C:\Users\timro\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# [MainProcess/INFO] mean: 1.0, mass: 0.152, coverage: 0.7835051546391752, density: 1.0 restricted_dimensions: 1

# %%
# box1.show_ppt()
# plt.show()

box1.show_tradeoff()
plt.title("Peeling Trajectory for Uncovered Demand Points")
plt.show()

# %%
box1.inspect(34)
box1.inspect(34, style="graph")
# box1.inspect(28)
# box1.inspect(28, style="graph")
plt.title("Box limits Nr. of Uncovered Demand Points")
plt.savefig("{}/{}/Analysis/ScenDisc/Box_Lim_NUDPs".format(case,output_folder),dpi=400,bbox_inches='tight')
plt.show()
# box1.inspect(48)
# Out:
# coverage    0.819588
# density      0.99375
# mass            0.16
# mean         0.99375
# res dim            1
# Name: 34, dtype: object
#
#             box 34
#                min       max                  qp values
# FL_range  2.004204  2.638628  [1.1020117903032392e-222]

# %%
print("Single dimension can't plot scatter")
box1.select(34)
# fig = box1.show_pairs_scatter()
# # fig.set_size_inches((12,12))
# # plt.tight_layout()
# plt.show()
# Out:
# Single dimension can't plot scatter

# %%
box2 = prim_obj.find_box()
# Out:
# [MainProcess/INFO] 1680 points remaining, containing 70 cases of interest
# C:\Users\timro\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# [MainProcess/INFO] box does not meet threshold criteria, value is 0.6730769230769231, returning dump box

# %%
print (prim_obj.stats_to_dataframe())
print (prim_obj.boxes_to_dataframe())
# Out:
#        coverage   density  mass  res_dim
# box 1  0.819588  0.993750  0.16        1
# box 2  0.180412  0.041667  0.84        0
#            box 1            box 2
#              min      max     min     max
# FL_range  2.0042  2.63863  2.0042  5.9995
